# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 8.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# ...
#      ------------------------------------- 965.4/965.4 kB 10.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 8.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 163.6/163.6 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies=['JL','Batman','Avengers','Ironman','Mask']
percentage=[23,31,30,19,7]

# %%
plt.scatter(movies,percentage)

# %%
plt.plot(movies,percentage,linestyle='dotted')

# %%
plt.bar(movies,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
pip install pie
# Out:
# ...
#
# ...
#      -------------------------------------- 108.4/108.4 kB 3.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 20.2/20.2 MB 8.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.5/42.5 MB 6.9 MB/s eta 0:00:00
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#      ---------------------------------------- 1.2/1.2 MB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 40.1/40.1 MB 6.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.1/9.1 MB 8.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 233.8/233.8 kB 14.0 MB/s eta 0:00:00
# ...
#      ------------------------------------- 340.1/340.1 kB 10.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 111.8/111.8 kB 6.4 MB/s eta 0:00:00
# ...

# %%
plt.pie(percentage,label=movies)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 plt.pie(percentage,label=movies)
#
# TypeError: pie() got an unexpected keyword argument 'label'

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 288.2/288.2 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')

# %%
import nympy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 import nympy as np
#
# ModuleNotFoundError: No module named 'nympy'

# %%
random=np.random.randn(100)

# %%
sns.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9968\1899859526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
planets=sns.load_dataset('tips')

# %%
planets
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
planets.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
planets.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y='tip',data=planets,col="time",hue="day",style="day",kind="line")

# %%
sns.regplot(x='total_bill',y='tip',data=planets)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
from sklearn.preprocessing import Normalization
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [80], line 1
# ----> 1 from Sklearn.preprocessing import Normalization
#
# ModuleNotFoundError: No module named 'Sklearn'
